# %%
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.transforms.functional as functional
import torch.optim as optim
from shoden_test_loader import shoden_loader
import numpy as np
import torchvision.models as models
import matplotlib.pyplot as plt
import random
from tqdm import tqdm 
# %matplotlib inline

# %%
from torchvision.utils import make_grid

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

loader = shoden_loader()
train = loader.run('train')
sample,_,path = next(iter(train))
# grid = make_grid(sample, nrow=16, padding=1, normalize=True)
# plt.figure(figsize=(12.8, 5.6))
# plt.imshow(grid.numpy().transpose(1,2,0))
# Out:
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 239, in _feed
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 239, in _feed
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 239, in _feed
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 239, in _feed
# Exception in thread QueueFeederThread:
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 239, in _feed
#     reader_close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     reader_close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 182, in close
# Exception ignored in: <function _ConnectionBase.__del__ at 0x7f638915cd30>
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 137, in __del__
#     self._close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     reader_close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self._close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     reader_close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     self.run()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 917, in run
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 271, in _feed
#     self._close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     reader_close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 182, in close
#     self._close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     self._close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     self.run()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 917, in run
#     self._close()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/connection.py", line 366, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 917, in run
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 917, in run
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 271, in _feed
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 271, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
#     self.run()
#   File "/opt/miniconda3/envs/develop/lib/python3.9/threading.py", line 917, in run
#         queue_sem.release()
# ValueError: semaphore or lock released too many times
# self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 271, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
#     self._target(*self._args, **self._kwargs)
#   File "/opt/miniconda3/envs/develop/lib/python3.9/multiprocessing/queues.py", line 271, in _feed
#     queue_sem.release()
# ValueError: semaphore or lock released too many times
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [15], line 8
#       6 loader = shoden_loader()
#       7 train = loader.run('train')
# ----> 8 sample,_,path = iter(train).next()
#       9 # grid = make_grid(sample, nrow=16, padding=1, normalize=True)
#      10 # plt.figure(figsize=(12.8, 5.6))
#      11 # plt.imshow(grid.numpy().transpose(1,2,0))
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataloader.py:359, in DataLoader.__iter__(self)
#     357     return self._iterator
#     358 else:
# --> 359     return self._get_iterator()
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataloader.py:305, in DataLoader._get_iterator(self)
#     303 else:
#     304     self.check_worker_number_rationality()
# --> 305     return _MultiProcessingDataLoaderIter(self)
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataloader.py:944, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#     942 _utils.signal_handling._set_SIGCHLD_handler()
#     943 self._worker_pids_set = True
# --> 944 self._reset(loader, first_iter=True)
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataloader.py:975, in _MultiProcessingDataLoaderIter._reset(self, loader, first_iter)
#     973 # prime the prefetch loop
#     974 for _ in range(self._prefetch_factor * self._num_workers):
# --> 975     self._try_put_index()
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataloader.py:1209, in _MultiProcessingDataLoaderIter._try_put_index(self)
#    1206 assert self._tasks_outstanding < self._prefetch_factor * self._num_workers
#    1208 try:
# -> 1209     index = self._next_index()
#    1210 except StopIteration:
#    1211     return
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataloader.py:512, in _BaseDataLoaderIter._next_index(self)
#     511 def _next_index(self):
# --> 512     return next(self._sampler_iter)
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/sampler.py:229, in BatchSampler.__iter__(self)
#     227 def __iter__(self) -> Iterator[List[int]]:
#     228     batch = []
# --> 229     for idx in self.sampler:
#     230         batch.append(idx)
#     231         if len(batch) == self.batch_size:
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/sampler.py:66, in SequentialSampler.__iter__(self)
#      65 def __iter__(self) -> Iterator[int]:
# ---> 66     return iter(range(len(self.data_source)))
#
# File ~/cleansing/my_project/src/shoden_test_loader.py:72, in shoden_dataset.__len__(self)
#      71 def __len__(self):
# ---> 72     if self.mode=="train":
#      73         return len(self.train_imgs["data"])
#      74     else:
#
# File /opt/miniconda3/envs/develop/lib/python3.9/site-packages/torch/utils/data/dataset.py:83, in Dataset.__getattr__(self, attribute_name)
#      81     return function
#      82 else:
# ---> 83     raise AttributeError
#
# AttributeError:
